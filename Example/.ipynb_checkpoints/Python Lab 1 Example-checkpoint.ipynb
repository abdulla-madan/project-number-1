# %% [markdown]
#  ## Everytime you change something in my_func.py you must restart the kernel and reimport (import my_func) before you rerun

# %%
import my_func

# %%
my_func.main()
# Out:
# Welcome to Habit Tracker!
# This app helps you build and maintain positive habits.
#
# === Habit Tracker ===
# 1. Add a new habit to track
# 2. Log completion of a habit
# 3. View habit streaks and statistics
# 4. Edit or remove habits
# 5. View all habits
# 6. Visualize habits (calendar view)
# 7. View rewards
# 8. Exit
#
# habits.csv exist.
#
# === Add a New Habit ===
#
# Frequency options: Daily, Weekly, Monthly
#
# Category examples: Health, Productivity, Learning, Fitness, Finance
#
# Habit 'test' added successfully!
# Start tracking this habit from 2022-01-01
#
# === Habit Tracker ===
# 1. Add a new habit to track
# 2. Log completion of a habit
# 3. View habit streaks and statistics
# 4. Edit or remove habits
# 5. View all habits
# 6. Visualize habits (calendar view)
# 7. View rewards
# 8. Exit
# Invalid choice. Please enter a number between 1 and 8.
#
# === Habit Tracker ===
# 1. Add a new habit to track
# 2. Log completion of a habit
# 3. View habit streaks and statistics
# 4. Edit or remove habits
# 5. View all habits
# 6. Visualize habits (calendar view)
# 7. View rewards
# 8. Exit
# Thank you for using Habit Tracker. Goodbye!
