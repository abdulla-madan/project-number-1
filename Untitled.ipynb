# %%
import plant

# %%
plant.main()
# Out:
# Welcome to  Plant Care Tracker
# This app is for plant enthusiasts to track their houseplants
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plant.main()
#
# File ~\DSB_PT_3\labs_projects\Python-Project\plant.py:78, in main()
#      75 print("This app is for plant enthusiasts to track their houseplants")
#      77 while True:
# ---> 78     choice = display_menu()
#      80     if choice == '1':
#      81         add_plant()
#
# NameError: name 'display_menu' is not defined
