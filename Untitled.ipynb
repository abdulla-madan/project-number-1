# %%
import plant

# %%
plant.main()
# Out:
# Welcome to  Plant Care Tracker
# This app is for plant enthusiasts to track their houseplants
#
# === plant Tracker ===
# 1. Add a new plant to track
# 2.  add Location of plant  in home
# 3. add date plant was acquired
# 4. add Watering frequency (in days)
# 5. add Sunlight needs (Low, Medium, High)
# Enter your choice (1-5):  1
# plants.csv exist.
#
# === plant Tracker ===
# 1. Add a new plant to track
# 2.  add Location of plant  in home
# 3. add date plant was acquired
# 4. add Watering frequency (in days)
# 5. add Sunlight needs (Low, Medium, High)

# %%
valid_frequencies = ['daily', 'weekly', 'monthly']
    print("\nFrequency options: Daily, Weekly, Monthly")
    while True:
        print("Please enter a valid frequency: Daily, Weekly, or Monthly.")
        frequency = input("Enter habit frequency: ").lower()
        if frequency in valid_frequencies:
            break
